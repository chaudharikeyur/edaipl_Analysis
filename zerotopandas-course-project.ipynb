# %% [markdown]
# ## Data Analysis with Python: Zero to Pandas - Course Project Guidelines
# #### (remove this cell before submission)
#
# Important links:
# - Make submissions here: https://jovian.ml/learn/data-analysis-with-python-zero-to-pandas/assignment/course-project
# - Ask questions here: https://jovian.ml/forum/t/course-project-on-exploratory-data-analysis-discuss-and-share-your-work/11684
# - Find interesting datasets here: https://jovian.ml/forum/t/recommended-datasets-for-course-project/11711
#
#
# This is the starter notebook for the course project for [Data Analysis with Python: Zero to Pandas](https://jovian.ml/learn/data-analysis-with-python-zero-to-pandas). You will pick a real-world dataset of your choice and apply the concepts learned in this course to perform exploratory data analysis. Use this starter notebook as an outline for your project . Focus on documentation and presentation - this Jupyter notebook will also serve as a project report, so make sure to include detailed explanations wherever possible using Markdown cells.
#
# ### Evaluation Criteria
#
# Your submission will be evaluated using the following criteria:
#
# * Dataset must contain at least 3 columns and 150 rows of data
# * You must ask and answer at least 4 questions about the dataset
# * Your submission must include at least 4 visualizations (graphs)
# * Your submission must include explanations using markdown cells, apart from the code.
# * Your work must not be plagiarized i.e. copy-pasted for somewhere else.
#
#
# Follow this step-by-step guide to work on your project.
#
#
# ### Step 1: Select a real-world dataset
#
# - Find an interesting dataset on this page: https://www.kaggle.com/datasets?fileType=csv
# - The data should be in CSV format, and should contain at least 3 columns and 150 rows
# - Download the dataset using the [`opendatasets` Python library](https://github.com/JovianML/opendatasets#opendatasets)
#
# Here's some sample code for downloading the [US Elections Dataset](https://www.kaggle.com/tunguz/us-elections-dataset):
#
# ```
# import opendatasets as od
# dataset_url = 'https://www.kaggle.com/tunguz/us-elections-dataset'
# od.download('https://www.kaggle.com/tunguz/us-elections-dataset')
# ```
#
# You can find a list of recommended datasets here: https://jovian.ml/forum/t/recommended-datasets-for-course-project/11711
#
# ### Step 2: Perform data preparation & cleaning
#
# - Load the dataset into a data frame using Pandas
# - Explore the number of rows & columns, ranges of values etc.
# - Handle missing, incorrect and invalid data
# - Perform any additional steps (parsing dates, creating additional columns, merging multiple dataset etc.)
#
#
# ### Step 3: Perform exploratory analysis & visualization
#
# - Compute the mean, sum, range and other interesting statistics for numeric columns
# - Explore distributions of numeric columns using histograms etc.
# - Explore relationship between columns using scatter plots, bar charts etc.
# - Make a note of interesting insights from the exploratory analysis
#
# ### Step 4: Ask & answer questions about the data
#
# - Ask at least 4 interesting questions about your dataset
# - Answer the questions either by computing the results using Numpy/Pandas or by plotting graphs using Matplotlib/Seaborn
# - Create new columns, merge multiple dataset and perform grouping/aggregation wherever necessary
# - Wherever you're using a library function from Pandas/Numpy/Matplotlib etc. explain briefly what it does
#
#
# ### Step 5: Summarize your inferences & write a conclusion
#
# - Write a summary of what you've learned from the analysis
# - Include interesting insights and graphs from previous sections
# - Share ideas for future work on the same topic using other relevant datasets
# - Share links to resources you found useful during your analysis
#
#
# ### Step 6: Make a submission & share your work
#
# - Upload your notebook to your Jovian.ml profile using `jovian.commit`.
# - **Make a submission here**: https://jovian.ml/learn/data-analysis-with-python-zero-to-pandas/assignment/course-project
# - Share your work on the forum: https://jovian.ml/forum/t/course-project-on-exploratory-data-analysis-discuss-and-share-your-work/11684
# - Browse through projects shared by other participants and give feedback
#
#
# ### (Optional) Step 7: Write a blog post
#
# - A blog post is a great way to present and showcase your work.
# - Sign up on [Medium.com](https://medium.com) to write a blog post for your project.
# - Copy over the explanations from your Jupyter notebook into your blog post, and [embed code cells & outputs](https://medium.com/jovianml/share-and-embed-jupyter-notebooks-online-with-jovian-ml-df709a03064e)
# - Check out the Jovian.ml Medium publication for inspiration: https://medium.com/jovianml
#
#
#
#
#
# ### Example Projects
#
# Refer to these projects for inspiration:
#
# * [Analyzing StackOverflow Developer Survey Results](https://jovian.ml/aakashns/python-eda-stackoverflow-survey)
#
# * [Analyzing Covid-19 data using Pandas](https://jovian.ml/aakashns/python-pandas-data-analysis)
#
# * [Analyzing your browser history using Pandas & Seaborn](https://medium.com/free-code-camp/understanding-my-browsing-pattern-using-pandas-and-seaborn-162b97e33e51) by Kartik Godawat
#
# * [WhatsApp Chat Data Analysis](https://jovian.ml/PrajwalPrashanth/whatsapp-chat-data-analysis) by Prajwal Prashanth
#
# * [Understanding the Gender Divide in Data Science Roles](https://medium.com/datadriveninvestor/exploratory-data-analysis-eda-understanding-the-gender-divide-in-data-science-roles-9faa5da44f5b) by Aakanksha N S
#
# * [2019 State of Javscript Survey Results](https://2019.stateofjs.com/demographics/)
#
# * [2020 Stack Overflow Developer Survey Results](https://insights.stackoverflow.com/survey/2020)
#
#
#
# **NOTE**: Remove this cell containing the instructions before making your submission. You can do using the "Edit > Delete Cells" menu option.

# %% [markdown]
# # Project Title - change this
#
# TODO - Write some introduction about your project here: describe the dataset, where you got it from, what you're trying to do with it, and which tools & techniques you're using. You can also mention about the course [Data Analysis with Python: Zero to Pandas](zerotopandas.com), and what you've learned from it.

# %% [markdown]
# ### How to run the code
#
# This is an executable [*Jupyter notebook*](https://jupyter.org) hosted on [Jovian.ml](https://www.jovian.ml), a platform for sharing data science projects. You can run and experiment with the code in a couple of ways: *using free online resources* (recommended) or *on your own computer*.
#
# #### Option 1: Running using free online resources (1-click, recommended)
#
# The easiest way to start executing this notebook is to click the "Run" button at the top of this page, and select "Run on Binder". This will run the notebook on [mybinder.org](https://mybinder.org), a free online service for running Jupyter notebooks. You can also select "Run on Colab" or "Run on Kaggle".
#
#
# #### Option 2: Running on your computer locally
#
# 1. Install Conda by [following these instructions](https://conda.io/projects/conda/en/latest/user-guide/install/index.html). Add Conda binaries to your system `PATH`, so you can use the `conda` command on your terminal.
#
# 2. Create a Conda environment and install the required libraries by running these commands on the terminal:
#
# ```
# conda create -n zerotopandas -y python=3.8
# conda activate zerotopandas
# pip install jovian jupyter numpy pandas matplotlib seaborn opendatasets --upgrade
# ```
#
# 3. Press the "Clone" button above to copy the command for downloading the notebook, and run it on the terminal. This will create a new directory and download the notebook. The command will look something like this:
#
# ```
# jovian clone notebook-owner/notebook-id
# ```
#
#
#
# 4. Enter the newly created directory using `cd directory-name` and start the Jupyter notebook.
#
# ```
# jupyter notebook
# ```
#
# You can now access Jupyter's web interface by clicking the link that shows up on the terminal or by visiting http://localhost:8888 on your browser. Click on the notebook file (it has a `.ipynb` extension) to open it.

# %% [markdown]
# ## Downloading the Dataset
#
# **TODO** - add some explanation here

# %% [markdown]
# > Instructions for downloading the dataset (delete this cell)
# >
# > - Find an interesting dataset on this page: https://www.kaggle.com/datasets?fileType=csv
# > - The data should be in CSV format, and should contain at least 3 columns and 150 rows
# > - Download the dataset using the [`opendatasets` Python library](https://github.com/JovianML/opendatasets#opendatasets)

# %%
# !pip install jovian opendatasets --upgrade --quiet

# %% [markdown]
# Let's begin by downloading the data, and listing the files within the dataset.

# %%
# Change this
dataset_url = 'https://www.kaggle.com/nowke9/ipldata'

# %%
import opendatasets as od
od.download(dataset_url)
# Out:
# 0it [00:00, ?it/s]
# Kaggle dataset ID:  nowke9/ipldata
# ...
# 1261568it [00:00, 4338767.01it/s]
# Extracting archive ./ipldata.zip to ./ipldata

# %% [markdown]
# The dataset has been downloaded and extracted.

# %%
# Change this
data_dir = './ipldata'

# %%
import os
os.listdir(data_dir)
# Out:
# ['deliveries.csv', 'matches.csv']

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %%
project_name = "project_ipl_analysis" # change this (use lowercase letters and hyphens only)

# %%
# !pip install jovian --upgrade -q

# %%
import jovian

# %%
jovian.commit(project=project_name)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Please enter your API key ( from https://jovian.ml/ ):
# API KEY: ········
# [jovian] Updating notebook "keyurchaudhari300/project-ipl-analysis" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/keyurchaudhari300/project-ipl-analysis
# 'https://jovian.ml/keyurchaudhari300/project-ipl-analysis'

# %% [markdown]
# ## Data Preparation and Cleaning
#
# **TODO** - Write some explanation here.

# %% [markdown]
# > Instructions (delete this cell):
# >
# > - Load the dataset into a data frame using Pandas
# > - Explore the number of rows & columns, ranges of values etc.
# > - Handle missing, incorrect and invalid data
# > - Perform any additional steps (parsing dates, creating additional columns, merging multiple dataset etc.)

# %%
import pandas as pd

# %%
raw_file = pd.read_csv('./ipldata/matches.csv')

# %%
type(raw_file)
# Out:
# pandas.core.frame.DataFrame

# %%
raw_file
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %% [markdown]
# the info() function returns the types of data in each columns

# %%
raw_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %% [markdown]
# The describe() function gives us the count, mean, standard deviation, minimum and maximun values of all the columns which have numerical data

# %%
raw_file.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %% [markdown]
# Getting the columns from the file

# %%
raw_file.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %% [markdown]
# the shape function returns the number of rows and columns in the data

# %%
raw_file.shape
# Out:
# (756, 18)

# %% [markdown]
# the head() and tail() functions return the first and last rows respectively depending on the argument passed

# %%
raw_file.head(15)
# Out:
#     id  season       city        date                        team1  \
# 0    1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1    2    2017       Pune  2017-04-06               Mumbai Indians
# 2    3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3    4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4    5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5    6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6    7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7    8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8    9    2017       Pune  2017-04-11             Delhi Daredevils
# 9   10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
# 10  11    2017    Kolkata  2017-04-13              Kings XI Punjab
# 11  12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 12  13    2017     Rajkot  2017-04-14       Rising Pune Supergiant
# ...

# %%
raw_file.tail(10)
# Out:
#         id  season           city      date                  team1  \
# 746  11342    2019         Mumbai  02/05/19         Mumbai Indians
# 747  11343    2019         Mohali  03/05/19        Kings XI Punjab
# 748  11344    2019          Delhi  04/05/19       Rajasthan Royals
# 749  11345    2019      Bengaluru  04/05/19    Sunrisers Hyderabad
# 750  11346    2019         Mohali  05/05/19    Chennai Super Kings
# 751  11347    2019         Mumbai  05/05/19  Kolkata Knight Riders
# 752  11412    2019        Chennai  07/05/19    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08/05/19    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10/05/19         Delhi Capitals
# 755  11415    2019      Hyderabad  12/05/19         Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 746          Sunrisers Hyderabad               Mumbai Indians           bat
# ...

# %% [markdown]
# The sample () function is used to get a random sample of items from an axis of object.

# %%
raw_file.sample(12)
# Out:
#        id  season        city        date                        team1  \
# 488   489    2014       Delhi  2014-05-10             Delhi Daredevils
# 409   410    2013     Chennai  2013-04-22             Rajasthan Royals
# 668  7926    2018     Kolkata    03/05/18          Chennai Super Kings
# 56     57    2017   Bangalore  2017-05-17          Sunrisers Hyderabad
# 125   126    2009   Cape Town  2009-04-23             Rajasthan Royals
# 269   270    2011     Kolkata  2011-04-30              Kings XI Punjab
# 72     73    2008  Chandigarh  2008-04-27             Delhi Daredevils
# 58     59    2017   Hyderabad  2017-05-21               Mumbai Indians
# 406   407    2013   Bangalore  2013-04-20             Rajasthan Royals
# 303   304    2011      Mumbai  2011-05-24  Royal Challengers Bangalore
# 526   527    2015     Kolkata  2015-04-30          Chennai Super Kings
# 585   586    2016  Chandigarh  2016-04-17      Rising Pune Supergiants
#
# ...

# %%
raw_file['vs_matches'] = raw_file.team1 + 'vs' + raw_file.team2
raw_file
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
winner_df = raw_file[['toss_winner', 'winner']]

# %%
winner_df
# Out:
#                      toss_winner                       winner
# 0    Royal Challengers Bangalore          Sunrisers Hyderabad
# 1         Rising Pune Supergiant       Rising Pune Supergiant
# 2          Kolkata Knight Riders        Kolkata Knight Riders
# 3                Kings XI Punjab              Kings XI Punjab
# 4    Royal Challengers Bangalore  Royal Challengers Bangalore
# ..                           ...                          ...
# 751               Mumbai Indians               Mumbai Indians
# 752          Chennai Super Kings               Mumbai Indians
# 753               Delhi Capitals               Delhi Capitals
# 754          Chennai Super Kings          Chennai Super Kings
# 755               Mumbai Indians               Mumbai Indians
#
# [756 rows x 2 columns]

# %%
dl_takers = raw_file.dl_applied > 0
print(dl_takers)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 751    False
# 752    False
# 753    False
# 754    False
# 755    False
# Name: dl_applied, Length: 756, dtype: bool

# %%
ipl_df = raw_file[raw_file.season > 2010]
ipl_df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
ipl_df.sort_values('win_by_runs', ascending=False).head(10)
# Out:
#         id  season        city        date                        team1  \
# 43      44    2017       Delhi  2017-05-06               Mumbai Indians
# 619    620    2016   Bangalore  2016-05-14  Royal Challengers Bangalore
# 556    557    2015   Bangalore  2015-05-06  Royal Challengers Bangalore
# 410    411    2013   Bangalore  2013-04-23  Royal Challengers Bangalore
# 706  11147    2019   Hyderabad    31/03/19          Sunrisers Hyderabad
# 295    296    2011  Dharamsala  2011-05-17              Kings XI Punjab
# 676   7934    2018     Kolkata    09/05/18               Mumbai Indians
# 8        9    2017        Pune  2017-04-11             Delhi Daredevils
# 541    542    2015     Chennai  2015-04-25          Chennai Super Kings
# 464    465    2014   Abu Dhabi  2014-04-21          Chennai Super Kings
#
#                            team2                  toss_winner toss_decision  \
# 43              Delhi Daredevils             Delhi Daredevils         field
# ...

# %%
ipl_df.sort_values('winner', ascending=False).tail(10)
# Out:
#         id  season       city        date                        team1  \
# 562    563    2015    Chennai  2015-05-10          Chennai Super Kings
# 319    320    2012    Chennai  2012-04-12  Royal Challengers Bangalore
# 553    554    2015    Chennai  2015-05-04          Chennai Super Kings
# 331    332    2012    Chennai  2012-04-19          Chennai Super Kings
# 546    547    2015    Chennai  2015-04-28          Chennai Super Kings
# 464    465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 300    301    2011      Delhi  2011-05-21             Delhi Daredevils
# 545    546    2015  Bangalore  2015-04-29  Royal Challengers Bangalore
# 570    571    2015  Bangalore  2015-05-17             Delhi Daredevils
# 744  11340    2019  Bengaluru    30/04/19  Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision  \
# 562             Rajasthan Royals          Chennai Super Kings           bat
# ...

# %%
ipl_df.sort_values('player_of_match', ascending=False).head(10)
# Out:
#       id  season       city        date                        team1  \
# 564  565    2015     Raipur  2015-05-12          Chennai Super Kings
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 249  250    2011     Mumbai  2011-04-17                Pune Warriors
# 494  495    2014  Bangalore  2014-05-13  Royal Challengers Bangalore
# 458  459    2014    Sharjah  2014-04-17             Delhi Daredevils
# 630  631    2016    Kolkata  2016-05-22        Kolkata Knight Riders
# 274  275    2011  Hyderabad  2011-05-03        Kolkata Knight Riders
# 377  378    2012       Pune  2012-05-22        Kolkata Knight Riders
# 426  427    2013    Kolkata  2013-05-03             Rajasthan Royals
# 620  621    2016    Kolkata  2016-05-14      Rising Pune Supergiants
#
#                            team2                  toss_winner toss_decision  \
# 564             Delhi Daredevils          Chennai Super Kings           bat
# ...

# %%
ipl_df.sort_values('win_by_wickets', ascending=False).tail(10)
# Out:
#         id  season        city        date                        team1  \
# 445    446    2013     Chennai  2013-05-14          Chennai Super Kings
# 444    445    2013      Ranchi  2013-05-15                Pune Warriors
# 439    440    2013  Chandigarh  2013-05-11          Sunrisers Hyderabad
# 437    438    2013       Delhi  2013-05-10  Royal Challengers Bangalore
# 436    437    2013        Pune  2013-05-09        Kolkata Knight Riders
# 434    435    2013   Hyderabad  2013-05-08          Chennai Super Kings
# 433    434    2013      Mumbai  2013-05-07               Mumbai Indians
# 429    430    2013      Mumbai  2013-05-05               Mumbai Indians
# 425    426    2013        Pune  2013-05-02  Royal Challengers Bangalore
# 755  11415    2019   Hyderabad    12/05/19               Mumbai Indians
#
#                      team2                  toss_winner toss_decision  result  \
# 445       Delhi Daredevils          Chennai Super Kings           bat  normal
# ...

# %%
ipl_df['player_of_match'].value_counts()
# Out:
# CH Gayle          20
# AB de Villiers    18
# DA Warner         16
# RG Sharma         14
# AM Rahane         12
#                   ..
# L Ngidi            1
# AD Mascarenhas     1
# Mohammed Shami     1
# JEC Franklin       1
# SA Yadav           1
# Name: player_of_match, Length: 182, dtype: int64

# %%
ipl_df['win_by_wickets'].value_counts()
# Out:
# 0     266
# 6      66
# 7      60
# 5      57
# 8      44
# 4      36
# 9      24
# 3      12
# 10      8
# 2       5
# 1       3
# Name: win_by_wickets, dtype: int64

# %%
ipl_df['winner'].value_counts()
# Out:
# Mumbai Indians                 86
# Kolkata Knight Riders          76
# Chennai Super Kings            74
# Royal Challengers Bangalore    63
# Kings XI Punjab                61
# Sunrisers Hyderabad            58
# Rajasthan Royals               50
# Delhi Daredevils               43
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Delhi Capitals                 10
# Deccan Chargers                10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "keyurchaudhari300/project-ipl-analysis" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/keyurchaudhari300/project-ipl-analysis
# 'https://jovian.ml/keyurchaudhari300/project-ipl-analysis'

# %% [markdown]
# ## Exploratory Analysis and Visualization
#
# **TODO** - write some explanation here.

# %% [markdown]
# > Instructions (delete this cell)
# >
# > - Compute the mean, sum, range and other interesting statistics for numeric columns
# > - Explore distributions of numeric columns using histograms etc.
# > - Explore relationship between columns using scatter plots, bar charts etc.
# > - Make a note of interesting insights from the exploratory analysis

# %% [markdown]
# Let's begin by importing`matplotlib.pyplot` and `seaborn`.

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# **TODO** - Explore one or more columns by plotting a graph below, and add some explanation about it

# %%
ipl_df.win_by_runs.sum()
# Out:
# 7597

# %%
ipl_df.win_by_wickets.sum()
# Out:
# 1942

# %% [markdown]
# **TODO** - Explore one or more columns by plotting a graph below, and add some explanation about it

# %%
ipl_df.groupby('vs_matches')[['winner', 'city','season']].cumsum()
# Out:
#      season
# 0      2017
# 1      2017
# 2      2017
# 3      2017
# 4      2017
# ..      ...
# 751   22165
# 752   14101
# 753    2019
# 754    4038
# 755   28212
#
# [581 rows x 1 columns]

# %%
ipl_df.groupby('season')['winner'].value_counts()
# Out:
# season  winner
# 2011    Chennai Super Kings            11
#         Mumbai Indians                 10
#         Royal Challengers Bangalore    10
#         Kolkata Knight Riders           8
#         Kings XI Punjab                 7
#                                        ..
# 2019    Kings XI Punjab                 6
#         Kolkata Knight Riders           6
#         Sunrisers Hyderabad             6
#         Rajasthan Royals                5
#         Royal Challengers Bangalore     5
# Name: winner, Length: 76, dtype: int64

# %% [markdown]
# exploring some data

# %%
ipl_df['toss_decision'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      field
# 1      field
# 2      field
# 3      field
# 4        bat
#        ...
# 751    field
# 752      bat
# 753    field
# 754    field
# 755      bat
# Name: toss_decision, Length: 581, dtype: object>

# %%
winners_win_by_more_wickets = ipl_df[ipl_df.win_by_wickets>9]
ipl_df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %% [markdown]
# Histogram graph

# %%
plt.title(' dl_applied ');
plt.hist(ipl_df. dl_applied);

# %% [markdown]
# **TODO** - Explore one or more columns by plotting a graph below, and add some explanation about it

# %%
plt.plot(ipl_df.win_by_runs, ipl_df.win_by_wickets);
plt.title('win by runs and wickets');

# %%
plt.title('Venue vs win by runs');
plt.bar(ipl_df.venue , ipl_df.win_by_runs);
plt.xticks(rotation = 90);
plt.xlabel('venue');
plt.ylabel( 'win_by_runs');

# %%
sns.barplot('venue', 'win_by_wickets', data = ipl_df);
plt.xticks(rotation = 90);

# %% [markdown]
# **TODO** - Explore one or more columns by plotting a graph below, and add some explanation about it

# %%
season_df = ipl_df[ipl_df.season > 2018]
plt.title('win by runs vs win by wickets');
sns.scatterplot('win_by_runs','win_by_wickets', s=100, data = ipl_df);
plt.xlabel("win_by_runs ");
plt.ylabel("win_by_wickets");

# %%
sns.barplot('winner', 'win_by_runs', data = ipl_df);
plt.xticks(rotation = 90);
plt.title('winners vs win by how may runs');
plt.xlabel("winner");
plt.ylabel("win_ny_runs");

# %%
plt.title('season and their win by wickets');
plt.bar(ipl_df.season, ipl_df.win_by_wickets);
plt.xticks(rotation = 90);
plt.xlabel("season");
plt.ylabel("win_by_wickets");

# %% [markdown]
# Let us save and upload our work to Jovian before continuing

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "keyurchaudhari300/project-ipl-analysis" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/keyurchaudhari300/project-ipl-analysis
# 'https://jovian.ml/keyurchaudhari300/project-ipl-analysis'

# %% [markdown]
# ## Asking and Answering Questions
#
# TODO - write some explanation here.

# %% [markdown]
# > Instructions (delete this cell)
# >
# > - Ask at least 5 interesting questions about your dataset
# > - Answer the questions either by computing the results using Numpy/Pandas or by plotting graphs using Matplotlib/Seaborn
# > - Create new columns, merge multiple dataset and perform grouping/aggregation wherever necessary
# > - Wherever you're using a library function from Pandas/Numpy/Matplotlib etc. explain briefly what it does

# %% [markdown]
# ### Q1: Which is the best defending team?

# %%
best_df_team=ipl_df.winner[ipl_df.win_by_runs!=0].mode()

# %%
best_df_team
# Out:
# 0    Mumbai Indians
# dtype: object

# %% [markdown]
# ### Q2: Which is the best-chasing team?

# %%
best_chase_team=ipl_df.winner[ipl_df.win_by_wickets!=0].mode()

# %%
best_chase_team
# Out:
# 0    Kolkata Knight Riders
# dtype: object

# %% [markdown]
# ### Q3:Which stadium is best for winning by runs?

# %%
venue_for_defend=ipl_df.venue[ipl_df.win_by_runs!=0].mode()

# %%
venue_for_defend
# Out:
# 0    Wankhede Stadium
# dtype: object

# %% [markdown]
# ### Q4: Which stadium is best for winning by wickets?

# %%
venue_for_chasing=ipl_df.venue[ipl_df.win_by_wickets!=0].mode()

# %%
venue_for_chasing
# Out:
# 0    Eden Gardens
# dtype: object

# %% [markdown]
# ### Q5: For an IPL team which stadium is best when they win the toss?

# %%
prediction=ipl_df.venue[ipl_df.toss_winner=='Chennai Super Kings'][ipl_df.winner=='Chennai Super Kings'].mode()

# %%
prediction
# Out:
# 0    MA Chidambaram Stadium, Chepauk
# dtype: object

# %% [markdown]
# ### Q6:How Many Man of the Matches the players are awarded amongst all the seasons?

# %%
ipl_df['player_of_match'].value_counts()
# Out:
# CH Gayle          20
# AB de Villiers    18
# DA Warner         16
# RG Sharma         14
# AM Rahane         12
#                   ..
# L Ngidi            1
# AD Mascarenhas     1
# Mohammed Shami     1
# JEC Franklin       1
# SA Yadav           1
# Name: player_of_match, Length: 182, dtype: int64

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "keyurchaudhari300/project-ipl-analysis" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/keyurchaudhari300/project-ipl-analysis
# 'https://jovian.ml/keyurchaudhari300/project-ipl-analysis'

# %% [markdown]
# ## Inferences and Conclusion :
#  * In all season after 2010 Chris Gayle is the player who hyas got most man of match awards so according to me all teams would be waiting to get Chris Gayle in their team
#  * Mumbai Indians is the only team who has won total 80+ matches among all teams between the season 2011-2019
#  * Graph has shown that generally most of team won matches on their home ground
#  * Chinnaswami and Feroz shah Kotla are the best stadium for batting
#  * Different factors effects on the team winning as we seen in the above examples and above-visualized data was accurate to the real world IPL statistics
#  * This is all about IPL Data Analysis the work is done as a part of a project by a team of aspiring Data Professionals while pursuing Internship/Training at TechTrunk Ventures – PVT LTD.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..

# %% [markdown]
# ## References and Future Work
#
# **TODO** - Write some explanation here: ideas for future projects using this dataset, and links to resources you found useful.

# %% [markdown]
# > Submission Instructions (delete this cell)
# >
# > - Upload your notebook to your Jovian.ml profile using `jovian.commit`.
# > - **Make a submission here**: https://jovian.ml/learn/data-analysis-with-python-zero-to-pandas/assignment/course-project
# > - Share your work on the forum: https://jovian.ml/forum/t/course-project-on-exploratory-data-analysis-discuss-and-share-your-work/11684
# > - Share your work on social media (Twitter, LinkedIn, Telegram etc.) and tag [@JovianML](https://twitter.com/jovianml)
# >
# > (Optional) Write a blog post
# >
# > - A blog post is a great way to present and showcase your work.
# > - Sign up on [Medium.com](https://medium.com) to write a blog post for your project.
# > - Copy over the explanations from your Jupyter notebook into your blog post, and [embed code cells & outputs](https://medium.com/jovianml/share-and-embed-jupyter-notebooks-online-with-jovian-ml-df709a03064e)
# > - Check out the Jovian.ml Medium publication for inspiration: https://medium.com/jovianml

# %%
import jovian

# %%
jovian.commit()
